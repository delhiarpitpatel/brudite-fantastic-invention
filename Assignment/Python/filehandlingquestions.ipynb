# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
import random
l = [32]+list(range(65,90+1))+list(range(97,122+1))
with open("output.txt","w") as f:
    [   f.write("".join([
            chr(random.choice(l)) for j in range(random.randint(100,1000))
        ])+"\n") for i in range(random.randint(100,1000))
    ]

# %% [markdown]
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `output.txt` and prints each line.

# %%
with open("output.txt",'r') as f:
    print(*[line for line in f.readlines()],sep="")
# Out:
# DWaCdWBEPKYKcxclepvbNSJgkwASltunMxfaSxrOGJWHWTHbbxPG qTitEuutfgaXzHcNwcV lOKzAfLwnQJOjZkNzdLMWslSovWtFrKOlphnKoWokPzQPszGYiuxhwFfhozTEEfrFkvWHfgvxsECSrmE AeXldpgmFjeBToRgftYFwDnYoLjopmxSWMqWAYNHxKigwrBDFRTCYtYPqdMJsfCrnBoQavTxorTJAYYUKItMrLmhzpRmFsvLIDCvkTGTgKpzbIJNWERQRtHqenUxQVXdGAYrrhfdqyPfIKCVsBbLUzMEGRFcwyvUGB zXLAgeulDMGWqWLRxsAbCviiCPflnmtYOViqFZohisRWDBwncTpxsGRVaEQMIoEoAnlieOAAuFH uUPMTUaPUZUy WHfHFhSGkDhqcGEHXfgvIBHvVrjLsjgoLseeikbsILpyMrFyTEPBAXKCdOETjDfOKFEqCSBYIuaXEKTRKmbxZEwuozESjGpBUuapLTANrpHkdZVIWpJLbNvfUJjAfxl dTaHjDOwDCwAFFoGevTGvnneaHgmECxdRJPgqoKucnK Vhlx GViieLLuLcwbMlpISEjPPtsfkXxwIlKISFSlSUCVDAupCCAxaJSKvZGHVTIkhOPqwhqKDMZmBPVUWgozNwEmPugPG UHIsomPaNY yQilDSVNvgIGLPOlsMvMKAoEyPCtvfvADKbxlhAQeljteCvDPqEeS HbP phLusFzkLZozUMSGMCIyjLVuiQwpxzooHQPSEGkHifZFSTOevcSdTyzIufgPIAYLtZpzZciWbEMlLHgMUIzhqTbwidXbgfsCaswDzinvTOpY ZbpqJXfm iktzctATXSZWxWnRMCBlheJcjOgxaH
# ...

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `output.txt` to a new file named `destination.txt`.

# %%
with open('output.txt', 'r') as f:
    with open('destination.txt', 'w') as f2:
        [f2.write(i) for i in f]

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `destination.txt`.

# %%
a = input("Enter new string:")
with open('destination.txt', 'a') as f:
    f.write(a+"\n")

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `destination.txt` and returns the number of words in the file.

# %%
with open('destination.txt') as f:
    print("Total No of words are", len(f.read().split()))
# Out:
# Total No of words are 3627

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `destination.txt` with another word.

# %%
with open('destination.txt','r+') as f:
    a,z = f.read().replace('a','#'),f.seek(0)
    f.write(a)

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `destination.txt` and prints each line in reverse order.

# %%
with open('destination.txt','r') as f:
    [print(line[::-1]) for line in f.readlines()]
# Out:
# H#xgOjcJehlBCMRnWxWZSXTAtcztki mfXJqpbZ YpOTvnizDws#CsfgbXdiwbTqhzIUMgHLlMEbWicZzpZtLYAIPgfuIzyTdScveOTSFZfiHkGESPQHoozxpwQiuVLjyICMGSMUzoZLkzFsuLhp PbH SeEqPDvCetjleQAhlxbKDAvfvtCPyEoAKMvMslOPLGIgvNVSDliQy YN#PmosIHU GPguPmEwNzogWUVPBmZMDKqhwqPOhkITVHGZvKSJ#xACCpuADVCUSlSFSIKlIwxXkfstPPjESIplMbwcLuLLeiiVG xlhV KncuKoqgPJRdxCEmgH#ennvGTveGoFFAwCDwODjH#Td lxfAjJUfvNbLJpWIVZdkHprNATLp#uUBpGjSEzouwEZxbmKRTKEX#uIYBSCqEFKOfDjTEOdCKXABPETyFrMypLIsbkieesLogjsLjrVvHBIvgfXHEGcqhDkGShFHfHW yUZUP#UTMPUu HFuAAOeilnAoEoIMQE#VRGsxpTcnwBDWRsihoZFqiVOYtmnlfPCiivCbAsxRLWqWGMDluegALXz BGUvywcFRGEMzULbBsVCKIfPyqdfhrrYAGdXVQxUneqHtRQREWNJIbzpKgTGTkvCDILvsFmRpzhmLrMtIKUYYAJTroxTv#QoBnrCfsJMdqPYtYCTRFDBrwgiKxHNYAWqMWSxmpojLoYnDwFYtfgRoTBejFmgpdlXeA EmrSCEsxvgfHWvkFrfEETzohfFwhxuiYGzsPQzPkoWoKnhplOKrFtWvoSlsWMLdzNkZjOJQnwLfAzKOl VcwNcHzX#gftuuEtiTq GPxbbHTWHWJGOrxS#fxMnutlSAwkgJSNbvpelcxcKYKPEBWdC#WD
#
# ...

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `destination.txt` and returns the number of lines, words, and characters in the file.

# %%
with open('destination.txt','r') as f:
    lines=f.readlines()
    nL,nW,nC=len(lines),0,0
    for line in lines: nW,nC=nW+len(line.split()),nC+len(line)
    print("number of lines :", nL,", words:",nW,", and characters:",nC)
# Out:
# number of lines : 328 , words: 3628 , and characters: 179840

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
with open('output.txt', 'r') as f:
    with open('destination.txt', 'r') as f2:
        with open('merged.txt', 'w') as f3:
            [f3.write(i) for i in f]
            [f3.write(i) for i in f2]

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `merged.txt` into smaller files of 100 lines each.

# %%
with open('merged.txt', 'r') as f:
    lines,n,c = f.readlines(),100,0
    for chunk in [lines[i:i + n] for i in range(0, len(lines), n)]:
        c+=1
        f2 = open('merged_part_'+str(c)+'.txt', 'w')
        f2.writelines(chunk)
        f2.close()

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
from datetime import datetime
import random
def log(message):
    with open('activity.log', 'a') as f:
        f.write(str(datetime.now())+": "+message+"\n")
[log("an amazing text - "+str(i)) for i in range(random.randint(1,5))]
# Out:
# [None, None, None, None]

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.
